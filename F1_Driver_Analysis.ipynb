# %%
# Import All Packages, Modules, and Libraries neeeded for this F1 Data Analysis Project.

# Data Manipulation, Cleaning, ETL Packages
import numpy as np
import pandas as pd
import statsmodels.api as sm 
import statsmodels.formula.api as smf 

# Data Visualization Packages
import seaborn as sns
import matplotlib.pyplot as plt


# Machine Learning Model Building Packages
from sklearn.model_selection import train_test_split , GridSearchCV , StratifiedKFold , KFold

# %%
# Read the Dataframe 
driver_df = pd.read_csv('archive/drivers.csv')
driver_df.head(20)
# Out:
#     driverId   driverRef number code   forename     surname         dob  \
# 0          1    hamilton     44  HAM      Lewis    Hamilton  1985-01-07
# 1          2    heidfeld     \N  HEI       Nick    Heidfeld  1977-05-10
# 2          3     rosberg      6  ROS       Nico     Rosberg  1985-06-27
# 3          4      alonso     14  ALO   Fernando      Alonso  1981-07-29
# 4          5  kovalainen     \N  KOV     Heikki  Kovalainen  1981-10-19
# 5          6    nakajima     \N  NAK     Kazuki    Nakajima  1985-01-11
# 6          7    bourdais     \N  BOU  Sébastien    Bourdais  1979-02-28
# 7          8   raikkonen      7  RAI       Kimi   Räikkönen  1979-10-17
# 8          9      kubica     88  KUB     Robert      Kubica  1984-12-07
# 9         10       glock     \N  GLO       Timo       Glock  1982-03-18
# 10        11        sato     \N  SAT     Takuma        Sato  1977-01-28
# 11        12   piquet_jr     \N  PIQ     Nelson  Piquet Jr.  1985-07-25
# ...

# %%
driver_standings_df = pd.read_csv('archive/driver_standings.csv')
driver_standings_df.head(20)
# Out:
#     driverStandingsId  raceId  driverId  points  position positionText  wins
# 0                   1      18         1    10.0         1            1     1
# 1                   2      18         2     8.0         2            2     0
# 2                   3      18         3     6.0         3            3     0
# 3                   4      18         4     5.0         4            4     0
# 4                   5      18         5     4.0         5            5     0
# 5                   6      18         6     3.0         6            6     0
# 6                   7      18         7     2.0         7            7     0
# 7                   8      18         8     1.0         8            8     0
# 8                   9      19         1    14.0         1            1     1
# 9                  10      19         2    11.0         3            3     0
# 10                 11      19         3     6.0         6            6     0
# ...
